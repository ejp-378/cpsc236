# %% [markdown]
# # Selections and Loops

# %% [markdown]
# ## 3.1 Letter Grade Converter
# Create a program that converts number grades to letter grades.
#
# ### Console:
# ```powershell
# Letter Grade Converter
#
# Enter numerical grade: 90
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 88
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 80
# Letter grade: B
#
# Continue? (y/n): y
#
# Enter numerical grade: 67
# Letter grade: C
#
# Continue? (y/n): y
#
# Enter numerical grade: 59
# Letter grade: F
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Assume that the user will enter valid integers for the grades.
# - The program should continue only if the user enters “y” or “Y” to continue.
# - The grading criteria is as follows:
#
# | Letter |	Range |
# |---|-------|
# | A |	88-100 |
# | B |	80-87 |
# | C |	67-79 |
# | D |	60-66 |
# | F |	<60 |

# %%
print("Letter Grade Converter")
print()
choice="y"
while choice.lower() =="y":
    grd = int(input("Enter numerical grade: "))
    if grd >=88 and grd <= 100:
        print("A")
    elif grd >= 80 and grd <= 87:
        print("B")
    elif grd >= 67 and grd <=79:
        print("C")
    elif grd >=60 and grd <= 66:
        print("D")
    elif grd <60:
        print("F")
    print()
    choice = input("Continue? (y/n): ")
    print()
    continue

print("Bye!")
# Out:
# Letter Grade Converter
#
# Enter numerical grade: 98
# A
#
# Continue? (y/n): y
#
# Enter numerical grade: 56
# F
#
# Continue? (y/n): y
#
# Enter numerical grade: 73
# C
#
# Continue? (y/n): n
#
# Bye!

# %% [markdown]
# ## 3.2 - Tip Calculator
# Create a program that calculates three options for an appropriate tip to leave after a meal at a restaurant.
#
# ### Console
# ```powershell
# Tip Calculator
#
# Cost of meal: 52.31
#
# 15%
# Tip amount:	7.85
# Total amount: 60.16
#
# 20%
# Tip amount:	10.46
# Total amount: 62.77
#
# 25%
# Tip amount:	13.08
# Total amount: 65.39
# ```
#
# ### Specifications:
# - The program should calculate and display the cost of tipping at 15%, 20%, or 25%.
# - Assume the user will enter valid data.
# - The program should round results to a maximum of two decimal places.

# %%
print("Tip Calculator")
pretax = float(input("Cost of Meal "))
print()
print("15%\t")
tip15= pretax*.15
print("Tip Amount: " + str(round(tip15,2)))
total1= tip15+pretax
total1=round(total1,2)
print("Total Amount: " + str(total1))
print()
print("20%\t")
tip20= pretax*.2
print("Tip Amount: " + str(round(tip20,2)))
total2= tip20+pretax
total2=round(total2,2)
print("Total Amount: " + str(total2))
print()
print("25%\t")
tip25= pretax*.25
print("Tip Amount: " + str(round(tip25,2)))
total3= tip25+pretax
total3=round(total3,2)
print("Total Amount: " + str(total3))
print()
# Out:
# Tip Calculator
# Cost of Meal 73.21
#
# 15%
# Tip Amount: 10.98
# Total Amount: 84.19
#
# 20%
# Tip Amount: 14.64
# Total Amount: 87.85
#
# 25%
# Tip Amount: 18.3
# Total Amount: 91.51

# %% [markdown]
# ## 3.3 - Change Calculator
# Create a program that calculates the coins needed to make change for the specified number of cents.
#
# ### Console
# ```powershell
# Change Calculator
#
# Enter number of cents (0-99): 99
#
# Quarters: 3
# Dimes:	2
# Nickels: 0
# Pennies: 4
#
# Continue? (y/n): y
#
# Enter number of cents (0-99): 55
#
# Quarters: 2
# Dimes:	0
# Nickels: 1
# Pennies: 0
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications
# - The program should display the minimum number of quarters, dimes, nickels, and pennies that one needs to make up the specified number of cents.
# - Assume that the user will enter a valid integer for the number of cents.
# - The program should continue only if the user enters “y” or “Y” to continue.

# %%
print("Change Calculator")
print()
choice = "y"

while choice.lower() == "y":
    cents = int(input("Enter number of cents (0-99): "))
    print()
    quarters = cents // 25
    remaining_cents = cents % 25
    dimes = remaining_cents // 10
    remaining_cents %= 10
    nickels = remaining_cents // 5
    pennies = remaining_cents % 5
    print("Quarters: " + str(quarters))
    print("Dimes: " + str(dimes))
    print("Nickels: " + str(nickels))
    print("Pennies: " + str(pennies))
    print()
    choice = input("Continue? (y/n) ")
    print()
    continue
print("Bye!")
# Out:
# Change Calculator
#
# Enter number of cents (0-99): 57
#
# Quarters: 2
# Dimes: 0
# Nickels: 1
# Pennies: 2
#
# Continue? (y/n) y
#
# Enter number of cents (0-99): 21
#
# Quarters: 0
# Dimes: 2
# Nickels: 0
# Pennies: 1
#
# Continue? (y/n) n
#
# Bye!

# %% [markdown]
# ## 3.4 - Table of Powers
# Create a program that displays a table of squares and cubes for the specified range of numbers.
#
# ### Console
# ```powershell
# Table of Powers
#
# Start number: 90
# Stop number: 100
#
# Number	Squared	Cubed
# ======	=======	=====
# 90      8100	729000
# 91      8281	753571
# 92      8464	778688
# 93      8649	804357
# 94      8836	830584
# 95      9025	857375
# 96      9216	884736
# 97      9409	912673
# 98      9604	941192
# 99      9801	970299
# 100     10000	1000000
# ```
#
# ### Specifications
# - The formulas for calculating squares and cubes are:
#
#     `square = x ** 2`
#
#     `cube = x ** 3`
#
# - Use tabs to align the columns.
# - Assume that the user will enter valid integers.
# - Make sure the user enters a start integer that’s less than the stop integer. If the user enters a start integer that’s greater than the stop integer, display an error message and give the user a chance to enter the integers again.

# %%
print("Table of Powers \n")

start = int(input("Start Number: "))
end = int(input("End Number: "))

while start > end :
    print("Invalid, Try Again. Start must be less than end ")
    start = int(input("Start Number: "))
    end = int(input("End Number: "))

print("Number\tsquared\tcubed")
print("======\t======\t======")

for i in range(start,end+1):
    square = i ** 2
    cube = i ** 3
    print(f"{i}\t{square}\t{cube}")
# Out:
# Table of Powers
#
# Start Number: 20
# End Number: 10
# Invalid, Try Again. Start must be less than end
# Start Number: 10
# End Number: 15
# Number	squared	cubed
# ======	======	======
# 10	100	1000
# 11	121	1331
# 12	144	1728
# 13	169	2197
# 14	196	2744
# 15	225	3375
